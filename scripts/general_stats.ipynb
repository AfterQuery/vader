# %%
pip install pandas openpyxl
# Out:
# Python(48200) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
path_example_cols = '../data/graded.xlsx'
df = pd.read_excel(path_example_cols, sheet_name=0, engine='openpyxl')

# %%
df
# Out:
#      Case             ID                                         Repository  \
# 0       1  1745335148884  https://github.com/saleor/saleor/blob/main/sal...
# 1       2  1745336228778  https://github.com/kunzbhatia/Library-Manageme...
# 2       3  1745337278378  https://github.com/rio-labs/rio/blob/main/fron...
# 3       4  1745344282769           https://github.com/heli-toon/LBSHS-LMS/
# 4       5  1745351755910           https://github.com/samir-k1/Firebase-Tut
# ..    ...            ...                                                ...
# 169   170  1745932579678  https://github.com/rndusr/torf/blob/master/tor...
# 170   171  1745933230563             https://github.com/kgarayev/filesearch
# 171   172  1745935258674  https://github.com/damonlynch/showinfilemanage...
# 172   173  1745935460553  https://github.com/requirejs/requirejs/tree/2.3.6
# 173   174  1745940782512  https://github.com/ChatGPTNextWeb/NextChat/blo...
#
# ...

# %%
df_rem = df.loc[:, df.columns.str.endswith('-remediation')]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))  # Adjust size as needed
df_rem.hist()
plt.tight_layout()  # Adjust spacing
plt.show()

# %%
df_rem.mean()
# Out:
# claude-3.7-sonnet-remediation    2.614943
# gemini-2.5-pro-remediation       2.637931
# gpt-4.1-remediation              2.454023
# gpt-4.5-remediation              2.459770
# o3-remediation                   2.729885
# grok-3-beta-remediation          2.568966
# dtype: float64

# %%
(df_rem.describe().loc[['mean', 'std', '25%', '50%', '75%']] / 5 * 100).round(2)
# Out:
#       claude-3.7-sonnet-remediation  gemini-2.5-pro-remediation  \
# mean                          52.30                       52.76
# std                           47.34                       47.22
# 25%                            0.00                        0.00
# 50%                           80.00                       80.00
# 75%                          100.00                      100.00
#
#       gpt-4.1-remediation  gpt-4.5-remediation  o3-remediation  \
# mean                49.08                49.20           54.60
# std                 46.65                47.92           48.67
# 25%                  0.00                 0.00            0.00
# 50%                 60.00                60.00           90.00
# 75%                100.00               100.00          100.00
#
#       grok-3-beta-remediation
# mean                    51.38
# std                     47.37
# 25%                      0.00
# 50%                     60.00
# 75%                    100.00

# %%
df_exp = df.loc[:, df.columns.str.endswith('-explanation')]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))  # Adjust size as needed
df_exp.hist()
plt.tight_layout()  # Adjust spacing
plt.show()

# %%
df_exp.mean()
# Out:
# claude-3.7-sonnet-explanation    1.074713
# gemini-2.5-pro-explanation       1.120690
# gpt-4.1-explanation              1.068966
# gpt-4.5-explanation              1.005747
# o3-explanation                   1.109195
# grok-3-beta-explanation          1.074713
# dtype: float64

# %%
(df_exp.describe().loc[['mean', 'std', '25%', '50%', '75%']]/2 * 100).round(2)
# Out:
#       claude-3.7-sonnet-explanation  gemini-2.5-pro-explanation  \
# mean                          53.74                       56.03
# std                           48.39                       48.75
# 25%                            0.00                        0.00
# 50%                          100.00                      100.00
# 75%                          100.00                      100.00
#
#       gpt-4.1-explanation  gpt-4.5-explanation  o3-explanation  \
# mean                53.45                50.29           55.46
# std                 49.15                48.83           49.41
# 25%                  0.00                 0.00            0.00
# 50%                100.00                50.00          100.00
# 75%                100.00               100.00          100.00
#
#       grok-3-beta-explanation
# mean                    53.74
# std                     48.98
# 25%                      0.00
# 50%                    100.00
# 75%                    100.00

# %%
df_o = df.loc[:, df.columns.str.endswith('-other')]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))  # Adjust size as needed
df_o.hist()
plt.tight_layout()  # Adjust spacing
plt.show()

# %%
df_o.mean()
# Out:
# claude-3.7-sonnet-other    1.551724
# gemini-2.5-pro-other       1.614943
# gpt-4.1-other              1.494253
# gpt-4.5-other              1.459770
# o3-other                   1.626437
# grok-3-beta-other          1.563218
# dtype: float64

# %%
(df_o.describe().loc[['mean', 'std', '25%', '50%', '75%']] / 3 * 100).round(2)
# Out:
#       claude-3.7-sonnet-other  gemini-2.5-pro-other  gpt-4.1-other  \
# mean                    51.72                 53.83          49.81
# std                     47.21                 47.76          47.24
# 25%                      0.00                  0.00           0.00
# 50%                     66.67                 66.67          66.67
# 75%                    100.00                100.00         100.00
#
#       gpt-4.5-other  o3-other  grok-3-beta-other
# mean          48.66     54.21              52.11
# std           47.76     48.40              48.00
# 25%            0.00      0.00               0.00
# 50%           66.67     83.33              66.67
# 75%          100.00    100.00             100.00
